# %% [markdown]
# # Learn the Basics

# %% [markdown]
# https://pytorch.org/tutorials/beginner/basics/intro.html

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
d = np.array([1,2,3,4,5])
e = np.array([6,7,8,9,10])
de = np.dot(d,e)
print(de)
# Out:
# 130

# %%
import time

a=np.random.rand(1000000)
b=np.random.rand(1000000)
# print(a)
# print(len(a))
# print(b)

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized version:" + str(1000*(toc-tic)) + "ms")


# non-vect version
c = 0
tic = time.time()
for i in range(1000000):
    c += a[i]*b[i]
toc = time.time()
print(c)
print("For loop:" + str(1000*(toc-tic)) + "ms")
# Out:
# 249606.36976850056
# Vectorized version:1.4178752899169922ms
# 249606.36976850723
# For loop:528.8360118865967ms
